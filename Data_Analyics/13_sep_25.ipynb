# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("matches - matches.csv")
# df.head(3)
df["city"]
# Out:
# 0      Hyderabad
# 1           Pune
# 2         Rajkot
# 3         Indore
# 4      Bangalore
#          ...
# 631       Raipur
# 632    Bangalore
# 633        Delhi
# 634        Delhi
# 635    Bangalore
# Name: city, Length: 636, dtype: object

# %%
def city_count(a):
    mask = df["city"].str.lower() == a.lower()
    return df[mask].shape[0]    

city_count("hyderabad")
# Out:
# 49

# %% [markdown]
# Q. find number of row where city == hyderabad and dl_applied == 1 .

# %%
mask0 = df["city"].str.lower() == 'hyderabad'.lower()
mask1 = df["dl_applied"] == 1
df[mask0 & mask1].shape[0]
# Out:
# 2

# %% [markdown]
# Q. find number of row where city == hyderabad and dl_applied == 1, Using function .

# %%
def city_count(a): # 
    mask0 = df["city"].str.lower() == a.lower()
    mask1 = df["dl_applied"] == 1
    mask = mask0 & mask1
    return df[mask].shape[0]  

city_count("hyderabad")
# Out:
# 2

# %%
## Find the count of team present in team1 and team2 column.. 
def Get_City_Name_count(team):
    mask = df['team1'].str.lower() == team.lower()
    mask1 = df['team2'].str.lower() == team.lower()
    return df[mask | mask1].shape[0]

Get_City_Name_count('sunrisers hyderabad')
# Out:
# 76

# %%
df['team1'].value_counts()
# Out:
# team1
# Mumbai Indians                 82
# Kings XI Punjab                77
# Chennai Super Kings            77
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Delhi Daredevils               63
# Rajasthan Royals               54
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  14
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: count, dtype: int64

# %% [markdown]
# # Plotting with Pandas
# 📌 Notes <br>
# "bar" -> bar chart

# %%
import matplotlib.pyplot as plt

# %%
df['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
df.sort_values(['city','season'],ascending=[True,False])
# Out:
#       id  season       city        date                        team1  \
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 474  475    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                    team2            toss_winner toss_decision  result  \
# ...

# %% [markdown]
# # ⛔Heandling Duplicates value using pandas

# %%
# df.drop_duplicates(subset=['city']) # duplicate value remove , on the basis of city column
df.drop_duplicates(subset=['player_of_match']).shape[0] # duplicate value remove , on the basis of player_of_match column
# Out:
# 202

# %%
df.drop_duplicates(subset=['player_of_match'], keep='last').shape[0] # duplicate value remove , on the basis of player_of_match column, keep last value
# Out:
# 202

# %%
# df.drop_duplicates(subset=['city','winner']).shape[0]
df.drop_duplicates(subset=['team1','team2']).shape[0] # duplicate value remove , on the basis of team1 and team2 column, keep first value by default
# Out:
# 127

# %% [markdown]
# Who won in each season?

# %%
won = df.drop_duplicates(subset=['season'],keep="last")
won[['season','winner']].sort_values('season').plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# # New Dataset...

# %%
data = pd.read_csv("Fortune 500 Companies US.csv",encoding = 'latin1')
